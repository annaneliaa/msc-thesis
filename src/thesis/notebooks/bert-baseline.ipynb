# %%
import sys
from pathlib import Path
import importlib
from dotenv import load_dotenv
from huggingface_hub import login
import os

# Search up the directory tree for 'src' directory
src_dir = None
for parent in Path.cwd().parents:
    candidate = parent / 'src'
    if candidate.exists():
        src_dir = candidate
        break

if src_dir is None:
    src_dir = Path.cwd() / 'src'  # fallback

sys.path.insert(0, str(src_dir))

import thesis.baselines.bert_classifier as bert

importlib.reload(bert)

from thesis.baselines.bert_classifier import main

# %%
# scenarios = ["fox", "harrison", "russellmitchell", "santos", "shaw", "wardbeck", "wheeler", "wilson"]
scenarios = ["fox"]

dataset = "alerts_csv"

model_name = "distilbert/distilbert-base-uncased"

# %%
load_dotenv()
token = os.getenv("HF_TOKEN")
login(token=token)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
for s in scenarios:
    main(dataset, s, model_name)
# Out:
# Running BERT baseline for scenario: fox
# Splitting data into train/val/test with ratios: 0.8 0.1 0.2
# Train size: 7217, Val size: 1031, Test size: 2062
# Loading tokenizer for model: distilbert/distilbert-base-uncased
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/stack/TUDelft/thesis/msc-thesis/venv/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:761, in hf_raise_for_status(response, endpoint_name)
#     760 try:
# --> 761     response.raise_for_status()
#     762 except httpx.HTTPStatusError as e:
#
# File ~/stack/TUDelft/thesis/msc-thesis/venv/lib/python3.13/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# ...
